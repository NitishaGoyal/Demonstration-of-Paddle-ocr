# %%
# !python -m pip install --upgrade pip
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hp\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hp\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hp\appdata\local\programs\python\python39\lib\site-packages)

# %%
# !python -m pip install paddlepaddle
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hp\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hp\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hp\appdata\local\programs\python\python39\lib\site-packages)

# %%
pip install paddlepaddle --user
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hp\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hp\appdata\local\programs\python\python39\lib\site-packages)
# ...

# %%
# !pip install paddleocr
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hp\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hp\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hp\appdata\local\programs\python\python39\lib\site-packages)

# %%
# !git clone https://github.com/PaddlePaddle/PaddleOCR
# Out:
# fatal: destination path 'PaddleOCR' already exists and is not an empty directory.

# %%
from paddleocr import PaddleOCR , draw_ocr
from matplotlib import pyplot as plt
import cv2
import os

# %%
ocr = PaddleOCR(lang='en')
# Out:
# [2024/10/20 17:03:05] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\HP/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\HP/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, m
# ...

# %%
img_path = os.path.join('.', 'flipkart images/marie.png')

# %%
img_path
# Out:
# '.\\flipkart images/marie.png'

# %%
result = ocr.ocr(img_path)
# Out:
# [2024/10/20 17:04:21] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/20 17:04:22] ppocr DEBUG: dt_boxes num : 4, elapsed : 1.5693552494049072
# [2024/10/20 17:04:24] ppocr DEBUG: rec_res num  : 4, elapsed : 1.4934182167053223

# %%
result
# Out:
# [[[[[165.0, 165.0], [230.0, 165.0], [230.0, 179.0], [165.0, 179.0]],
#    ('PARLE', 0.9971699714660645)],
#   [[[104.0, 198.0], [292.0, 194.0], [293.0, 239.0], [105.0, 243.0]],
#    ('MARIE', 0.9973899126052856)],
#   [[[89.0, 314.0], [167.0, 314.0], [167.0, 327.0], [89.0, 327.0]],
#    ('STAYFRESH', 0.9914583563804626)],
#   [[[89.0, 327.0], [177.0, 327.0], [177.0, 340.0], [89.0, 340.0]],
#    ('PACKS.INSIDE', 0.9728302955627441)]]]

# %%
result[0][1][0]
# Out:
# [[104.0, 198.0], [292.0, 194.0], [293.0, 239.0], [105.0, 243.0]]

# %%
for res in result:
    print(res[1][0])
# Out:
# [[104.0, 198.0], [292.0, 194.0], [293.0, 239.0], [105.0, 243.0]]

# %%
for item in result[0]:
    text = item[1][0]  # Accessing the text from the second element of the tuple
    print(text)
# Out:
# PARLE
# MARIE
# STAYFRESH
# PACKS.INSIDE

# %%
boxes = [res[0] for res in result[0]]
text = [res[1][0] for res in result[0]]
scores = [res[1][1] for res in result[0]]

# %%
import os

# %%
font_path = os.path.join('PaddleOCR' , 'doc' , 'fonts' , 'latin.ttf')

# %%
img = cv2.imread(img_path)
img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(15,15))
annotated = draw_ocr(img , boxes , text , scores , font_path = font_path)
plt.imshow(annotated)

# %%
img_path = os.path.join('.', 'flipkart images/Screenshot 2024-10-20 165532.png')

# %%
result = ocr.ocr(img_path)
# Out:
# [2024/10/20 17:07:27] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/20 17:07:28] ppocr DEBUG: dt_boxes num : 5, elapsed : 1.1504180431365967
# [2024/10/20 17:07:30] ppocr DEBUG: rec_res num  : 5, elapsed : 2.4287309646606445

# %%
boxes = [res[0] for res in result[0]]
text = [res[1][0] for res in result[0]]
scores = [res[1][1] for res in result[0]]

# %%
import os

# %%
font_path = os.path.join('PaddleOCR' , 'doc' , 'fonts' , 'latin.ttf')

# %%
img = cv2.imread(img_path)
img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(15,15))
annotated = draw_ocr(img , boxes , text , scores , font_path = font_path)
plt.imshow(annotated)

# %%
img_path = os.path.join('.','flipkart images/Screenshot 2024-10-20 165224.png')

# %%
result = ocr.ocr(img_path)
# Out:
# [2024/10/20 17:09:49] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/20 17:09:51] ppocr DEBUG: dt_boxes num : 10, elapsed : 1.576181411743164
# [2024/10/20 17:09:54] ppocr DEBUG: rec_res num  : 10, elapsed : 2.889665126800537

# %%
boxes = [res[0] for res in result[0]]
text = [res[1][0] for res in result[0]]
scores = [res[1][1] for res in result[0]]

# %%
import os

# %%
font_path = os.path.join('PaddleOCR' , 'doc' , 'fonts' , 'latin.ttf')

# %%
img = cv2.imread(img_path)
img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(15,15))
annotated = draw_ocr(img , boxes , text , scores , font_path = font_path)
plt.imshow(annotated)

# %%
img_path = os.path.join('.','flipkart images/Screenshot 2024-10-20 165710.png')

# %%
result = ocr.ocr(img_path)
boxes = [res[0] for res in result[0]]
text = [res[1][0] for res in result[0]]
scores = [res[1][1] for res in result[0]]
# Out:
# [2024/10/20 17:13:21] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/20 17:13:23] ppocr DEBUG: dt_boxes num : 7, elapsed : 1.3545022010803223
# [2024/10/20 17:13:24] ppocr DEBUG: rec_res num  : 7, elapsed : 1.6447553634643555

# %%
result = ocr.ocr(img_path)
boxes = [res[0] for res in result[0]]
text = [res[1][0] for res in result[0]]
scores = [res[1][1] for res in result[0]]

# %%
img_path = os.path.join('.','flipkart images/atta.png')

# %%
result = ocr.ocr(img_path)
boxes = [res[0] for res in result[0]]
text = [res[1][0] for res in result[0]]
scores = [res[1][1] for res in result[0]]
# Out:
# [2024/10/20 17:18:56] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/20 17:18:57] ppocr DEBUG: dt_boxes num : 28, elapsed : 1.6022093296051025
# [2024/10/20 17:19:03] ppocr DEBUG: rec_res num  : 28, elapsed : 5.19905424118042

# %%
import os

# %%
font_path = os.path.join('PaddleOCR' , 'doc' , 'fonts' , 'latin.ttf')

# %%
img = cv2.imread(img_path)
img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(15,15))
annotated = draw_ocr(img , boxes , text , scores , font_path = font_path)
plt.imshow(annotated)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.save("ocr_model.h5")
#
# NameError: name 'model' is not defined
